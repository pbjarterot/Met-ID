# %%
import pymzml
import os
import matplotlib.pyplot as plt
import numpy as np

def get_mzml_files_in_subfolders(folder_path):
    mzml_files = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith(".mzML"):
                mzml_files.append(os.path.join(root, file))
    return mzml_files

# %%
folder_path = '//mms2.farmbio.uu.se/imaging3/NewProjects2023/Metabolite_Identification/202306_FMP10_MSMS_standards/'
mzml_files = get_mzml_files_in_subfolders(folder_path)

print(f"Found {len(mzml_files)} .mzML files:")

for mzml_file in mzml_files[4:5]:
    run = pymzml.run.Reader(mzml_file)
    for n, spec in enumerate(run):
        spectra1 = spec.removeNoise().removeNoise().removeNoise().removeNoise().peaks("centroided") 
        print(len(spectra1))      
        print(spec.estimated_noise_level())
        spectra2 = spec.remove_noise(noise_level=spec.estimated_noise_level()*1.5).peaks("centroided")
# Out:
# Found 789 .mzML files:
# 1084
# 50164.58242392499

# %%
x2, y2 = [], []
[(x2.append(i), y2.append(j)) for (i, j) in spectra2]

x, y = [], []
[(x.append(i), y.append(j)) for (i, j) in spectra1]
# Out:
# [(None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
#  (None, None),
# ...

# %%
plt.figure(figsize=(25, 7))
plt.stem(x, np.log10(y))
#plt.ylim(0, 1.2)
plt.show()

# %%
plt.figure(figsize=(25, 7))
plt.stem(x2, np.log10(y2))
#plt.ylim(0, 1.2)
plt.show()
